# %%
import pandas as pd

# %%
#Q1: Creating a DataFrame from a dictionary

# %%
employee_data = {
    'Employee ID': [101, 102, 103, 104, 105],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, 40, 45],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'HR'],
    'Salary': [50000, 60000, 70000, 80000, 90000]
}

# %%
df = pd.DataFrame(employee_data)

# %%
df
# Out:
#    Employee ID     Name  Age Department  Salary
# 0          101    Alice   25         HR   50000
# 1          102      Bob   30         IT   60000
# 2          103  Charlie   35    Finance   70000
# 3          104    David   40         IT   80000
# 4          105      Eve   45         HR   90000

# %%
# Display first 5 records
df.head()
# Out:
#    Employee ID     Name  Age Department  Salary
# 0          101    Alice   25         HR   50000
# 1          102      Bob   30         IT   60000
# 2          103  Charlie   35    Finance   70000
# 3          104    David   40         IT   80000
# 4          105      Eve   45         HR   90000

# %%
# Get basic dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee ID  5 non-null      int64
#  1   Name         5 non-null      object
#  2   Age          5 non-null      int64
#  3   Department   5 non-null      object
#  4   Salary       5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 332.0+ bytes

# %%
# Show summary statistics
df.describe()
# Out:
#        Employee ID        Age        Salary
# count     5.000000   5.000000      5.000000
# mean    103.000000  35.000000  70000.000000
# std       1.581139   7.905694  15811.388301
# min     101.000000  25.000000  50000.000000
# 25%     102.000000  30.000000  60000.000000
# 50%     103.000000  35.000000  70000.000000
# 75%     104.000000  40.000000  80000.000000
# max     105.000000  45.000000  90000.000000

# %%
# Q2: Loading a CSV file into a DataFrame

# %%
df_csv = pd.read_csv(r"C:\Users\likitha\Downloads\cleaned_titanic.csv")

# %%
df_csv
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# Check for missing values in each column
df_csv.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Get the number of unique values in each column
df_csv.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          148
# Embarked         3
# dtype: int64

# %%
# Save the cleaned DataFrame into a new CSV file
df_csv.dropna(inplace=True)  # Removing missing values 
cleaned_csv_file_path = "cleaned_data.csv"   # naming the csv file  
df_csv.to_csv(cleaned_csv_file_path, index=False)    # dataframe to csv file
